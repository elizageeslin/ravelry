# %% [markdown]
# # Getting Started - Collecting Data using the API

# %% [markdown]
# This file contains the code to extract data from ravelry.com using the API.
#
# API documentation: https://www.ravelry.com/api
#
# Used read-only credentials for data retrieval. I already had a ravelry account (for my knitting work), but it is free to create an account to get the API keys.
#
# Got data for patterns sorted by popularity. I collected data for about 10,000 patterns, so it took a long time to do the final download, which is why I am keeping this in a separate file.

# %%
import http.client
import base64
import json
import requests
import pandas as pd

# %%
# load API token username and password
# credentials that are tied to my ravelry account removed prior to submission.
authUsername = #ADD IT IN HERE
authPassword = #ADD IT IN HERE

# test function - scrap the top 1000 patterns - not actually used in the final scraping, just wanted to see how it worked
def get_pattern_info_test(query, authUsername, authPassword):
    res = requests.get('https://api.ravelry.com/patterns/search.json?query={}&sort=projects&page_size=1000&page=80'.format(query),
                       auth=requests.auth.HTTPBasicAuth(authUsername, authPassword))
    return res

# %%
# run test function - scrap the top 1000 patterns - not actually used in the final scraping, just wanted to see how it worked

test_res = get_pattern_info_test('', authUsername, authPassword)
test_result = json.loads(test_res.content)
test_result['patterns']
patterns_test_df = pd.DataFrame(test_result['patterns'])

patterns_test_df
# Out:
#       free      id                                 name  \
# 0    False  470186               Unraveling the Mystery
# 1     True  470281                Cute and Easy Cat Hat
# 2     True  471196                  Tristan's Triangles
# 3     True  471546                         8-Hour Shawl
# 4    False  473633                               Maylee
# ..     ...     ...                                  ...
# 995   True   28592                       Bonnie Blanket
# 996  False   29095                 Lavender Hat & Scarf
# 997  False   29479                        Forest jacket
# 998  False   29598  Mittens, Mittens, Mittens  (AC-001)
# 999  False   29674     Winnie-the-Pooh & Friends Afghan
#
#                            permalink personal_attributes  \
# 0             unraveling-the-mystery                None
# 1              cute-and-easy-cat-hat                None
# 2                 tristans-triangles                None
# 3                     8-hour-shawl-2                None
# 4                             maylee                None
# ..                               ...                 ...
# 995                   bonnie-blanket                None
# 996              lavender-hat--scarf                None
# 997                    forest-jacket                None
# 998   mittens-mittens-mittens-ac-001                None
# 999  winnie-the-pooh--friends-afghan                None
#
#                                            first_photo  \
# 0    {'id': 38062368, 'sort_order': 1, 'user_id': 1...
# 1    {'id': 37994073, 'sort_order': 1, 'user_id': 3...
# 2    {'id': 43498361, 'sort_order': 1, 'user_id': 3...
# 3    {'id': 38135293, 'sort_order': 1, 'user_id': 4...
# 4    {'id': 39596645, 'sort_order': 1, 'user_id': 7...
# ..                                                 ...
# 995  {'id': 15201313, 'sort_order': 1, 'user_id': 1...
# 996  {'id': 3216013, 'sort_order': 1, 'user_id': 38...
# 997  {'id': 742896, 'sort_order': 1, 'user_id': 217...
# 998  {'id': 70739190, 'sort_order': 1, 'user_id': 4...
# 999  {'id': 6525359, 'sort_order': 1, 'user_id': 79...
#
#                                               designer  \
# 0    {'crochet_pattern_count': 0, 'favorites_count'...
# 1    {'crochet_pattern_count': 85, 'favorites_count...
# 2    {'crochet_pattern_count': 0, 'favorites_count'...
# 3    {'crochet_pattern_count': 95, 'favorites_count...
# 4    {'crochet_pattern_count': 0, 'favorites_count'...
# ..                                                 ...
# 995  {'crochet_pattern_count': 21, 'favorites_count...
# 996  {'crochet_pattern_count': 0, 'favorites_count'...
# 997  {'crochet_pattern_count': 13, 'favorites_count...
# 998  {'crochet_pattern_count': 0, 'favorites_count'...
# 999  {'crochet_pattern_count': 457, 'favorites_coun...
#
#                                         pattern_author  \
# 0    {'crochet_pattern_count': 0, 'favorites_count'...
# 1    {'crochet_pattern_count': 85, 'favorites_count...
# 2    {'crochet_pattern_count': 0, 'favorites_count'...
# 3    {'crochet_pattern_count': 95, 'favorites_count...
# 4    {'crochet_pattern_count': 0, 'favorites_count'...
# ..                                                 ...
# 995  {'crochet_pattern_count': 21, 'favorites_count...
# 996  {'crochet_pattern_count': 0, 'favorites_count'...
# 997  {'crochet_pattern_count': 13, 'favorites_count...
# 998  {'crochet_pattern_count': 0, 'favorites_count'...
# 999  {'crochet_pattern_count': 457, 'favorites_coun...
#
#                                        pattern_sources
# 0    [{'amazon_rating': None, 'amazon_reviews': Non...
# 1    [{'amazon_rating': None, 'amazon_reviews': Non...
# 2    [{'amazon_rating': None, 'amazon_reviews': Non...
# 3    [{'amazon_rating': None, 'amazon_reviews': Non...
# 4    [{'amazon_rating': None, 'amazon_reviews': Non...
# ..                                                 ...
# 995  [{'amazon_rating': None, 'amazon_reviews': Non...
# 996  [{'amazon_rating': None, 'amazon_reviews': Non...
# 997  [{'amazon_rating': None, 'amazon_reviews': Non...
# 998  [{'amazon_rating': None, 'amazon_reviews': Non...
# 999  [{'amazon_rating': None, 'amazon_reviews': Non...
#
# [1000 rows x 9 columns]

# %%
# function to scrap the first 10 pages (1000 patterns on each page) of patterns sorted by popularity and what worked during testing

def get_pattern_info(authUsername, authPassword):
    pattern_ids = []
    for page in range(1, 11):
        res = requests.get('https://api.ravelry.com/patterns/search.json?&sort=popularity&page_size=1000&page=' + str(page),
                       auth=requests.auth.HTTPBasicAuth(authUsername, authPassword))
        result = json.loads(res.content)
        patterns_df = pd.DataFrame(result['patterns'])
        pattern_ids.append(patterns_df.id.tolist())
    return pattern_ids

# %%
# returns pattern ids as integers, list of lists (a list for each page of results)

pattern_ids = get_pattern_info(authUsername, authPassword)

# %%
# flatten list, and change integers into strings

ids_list = [str(patt_id) for sublist in pattern_ids for patt_id in sublist]

print(ids_list)
# Out:
', '54', '714659', '622283', '369042', '1033464', '1295749', '1246768', '1334881', '944225', '1347408', '1004612', '1185869', '941441', '1106023', '56527', '1243707', '903194', '1247893', '1185353', '594862', '1062510', '1092343', '497242', '1171668', '548384', '1080133', '1021796', '1244549', '930451', '594', '963484', '1083371', '1235715', '1233976', '74682', '714001', '1135501', '629906', '733275', '864904', '522385', '1306929', '1325806', '75857', '1157225', '243083', '1288002', '153935', '752655', '1338173', '817955', '1036856', '1170258', '1277280', '497126', '986433', '405278', '1332977', '496025', '772466', '1072478', '1006482', '736343', '1167548', '1292287', '772032', '1310169', '1048806', '1276364', '959956', '117714', '949070', '852742', '996455', '913275', '98 ...

# %%
# next step is to retreive details for an individual pattern id.

#test to see if I can do it once
test1 = requests.get('https://api.ravelry.com/patterns.json?ids=' +
                     str(990044), auth=requests.auth.HTTPBasicAuth(authUsername, authPassword))
result1 = json.loads(test1.content)
pattern_detail_test_df = pd.DataFrame(result1['patterns']).T

pattern_detail_test_df
# Out:
#        comments_count                                              craft  \
# 990044             80  {'id': 2, 'name': 'Knitting', 'permalink': 'kn...
#
#                        created_at currency currency_symbol difficulty_average  \
# 990044  2019/12/23 10:25:36 -0500      GBP               £           2.407254
#
#        difficulty_count                                  download_location  \
# 990044             2178  {'type': 'ravelry', 'free': False, 'url': 'htt...
#
#        downloadable favorites_count  ... unlisted_product_ids  \
# 990044         True           42072  ...                 None
#
#                        updated_at                                      url  \
# 990044  2023/07/03 03:55:16 -0400  https://ysolda.com/products/musselburgh
#
#        volumes_in_library yardage yardage_description yardage_max  \
# 990044               None     130     130 - 610 yards         610
#
#        yarn_list_type                                        yarn_weight  \
# 990044              2  {'crochet_gauge': None, 'id': 15, 'knit_gauge'...
#
#                    yarn_weight_description
# 990044  Any gauge - designed for any gauge
#
# [1 rows x 55 columns]

# %%
# create final scraping function that pulls in pattern details for every pattern in the top 10,000 popularity.
# at first I tried to run it in batches of 50, 25, or 10, but that was timing out
# I re-wrote the fuction to loop through all the ids one at a time and that worked better

def get_pattern_details(authUsername, authPassword, pattern_ids):
    pattern_details_dataframes = []

    for id in pattern_ids:
        url = f'https://api.ravelry.com/patterns.json?ids={id}'
        response = requests.get(url, auth=requests.auth.HTTPBasicAuth(authUsername, authPassword))
        result = json.loads(response.content)
        details_df = pd.DataFrame(result['patterns']).T
        pattern_details_dataframes.append(details_df)

    pattern_details_df = pd.concat(pattern_details_dataframes).reset_index().rename(columns={'index': 'patt_id'})
    return pattern_details_df

# %%
# run and save the pattern_details file. This takes a bit to run, so I am going to do my data cleaning & analysis in another file.

pattern_details = get_pattern_details(authUsername, authPassword, ids_list)
pattern_details.to_csv('pattern_details.csv', index=False)
